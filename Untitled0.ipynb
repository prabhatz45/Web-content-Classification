# %%
pip install datasets transformers langchain-core langchain-groq datasets langchain-groq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.9/108.9 kB 7.5 MB/s eta 0:00:00
# ...

# %%
from datasets import load_dataset

# Load AG News dataset
dataset = load_dataset("ag_news")
train_data = dataset["train"]
test_data = dataset["test"]

# Inspect the dataset
print(train_data[0])
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/8.07k [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/18.6M [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/1.23M [00:00<?, ?B/s]
# ...
# Generating test split:   0%|          | 0/7600 [00:00<?, ? examples/s]
# {'text': "Wall St. Bears Claw Back Into the Black (Reuters) Reuters - Short-sellers, Wall Street's dwindling\\band of ultra-cynics, are seeing green again.", 'label': 2}

# %%
from langchain_core.prompts import PromptTemplate
from langchain_groq import ChatGroq

# Initialize the LLaMA 3.1 model
llm = ChatGroq(
    temperature=0,
    groq_api_key='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',
    model_name="llama-3.1-70b-versatile"
)

# %%
def format_prompt(example):
    prompt = (
        "Classify the following text into one of the categories: World, Sports, Business, or Sci/Tech.\n\n"
        f"Text: {example['text']}\n\n"
        "Category:"
    )
    return {"prompt": prompt, "label": example["label"]}

# Use `map()` and ensure the new fields are added
train_prompts = train_data.map(format_prompt)
test_prompts = test_data.map(format_prompt)

# Inspect the first example
print(train_prompts[0])  # Should contain 'prompt' and 'label' fields
# Out:
# {'text': "Wall St. Bears Claw Back Into the Black (Reuters) Reuters - Short-sellers, Wall Street's dwindling\\band of ultra-cynics, are seeing green again.", 'label': 2, 'prompt': "Classify the following text into one of the categories: World, Sports, Business, or Sci/Tech.\n\nText: Wall St. Bears Claw Back Into the Black (Reuters) Reuters - Short-sellers, Wall Street's dwindling\\band of ultra-cynics, are seeing green again.\n\nCategory:"}

# %%
# Predict on a small sample for demonstration
for i in range(5):  # Loop using indices
    prompt = train_prompts[i]["prompt"]  # Access 'prompt' field correctly
    predicted_category = predict_category(llm, prompt)
    print(f"Prompt: {prompt}\nPrediction: {predicted_category}\n")
# Out:
# <ipython-input-7-f1617d1be933>:2: LangChainDeprecationWarning: The method `BaseChatModel.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   response = llm(prompt)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-b5494fa5e8e8> in <cell line: 2>()
#       2 for i in range(5):  # Loop using indices
#       3     prompt = train_prompts[i]["prompt"]  # Access 'prompt' field correctly
# ----> 4     predicted_category = predict_category(llm, prompt)
#       5     print(f"Prompt: {prompt}\nPrediction: {predicted_category}\n")
#
# <ipython-input-7-f1617d1be933> in predict_category(llm, prompt)
#       1 def predict_category(llm, prompt):
# ----> 2     response = llm(prompt)
#       3     return response.strip()
#       4
#       5 # Predict on a small sample for demonstration
#
# ...
